# %%
import pandas as pd

# %%
from pathlib import Path
import glob

# %%
[Path(p) for p in glob.glob("../models/logs/*/full*.csv")]
# Out:
# [PosixPath('../models/logs/cnn_extended/full_cnn_extended_image_random.csv'),
#  PosixPath('../models/logs/cnn_extended/full_cnn_extended_patient_random.csv'),
#  PosixPath('../models/logs/ensemble_efficientnetv2-s/full_ensemble_efficientnetv2-s_efficientnetv2-s_patient_random.csv'),
#  PosixPath('../models/logs/ensemble_efficientnetv2-s/full_ensemble_efficientnetv2-s_efficientnetv2-s_image_random.csv'),
#  PosixPath('../models/logs/ensemble_inception_v3/full_ensemble_inception_v3_inception_v3_patient_random.csv'),
#  PosixPath('../models/logs/ensemble_inception_v3/full_ensemble_inception_v3_inception_v3_image_random.csv'),
#  PosixPath('../models/logs/ensemble_resnet50v2/full_ensemble_resnet50v2_resnet50v2_image_random.csv'),
#  PosixPath('../models/logs/ensemble_resnet50v2/full_ensemble_resnet50v2_resnet50v2_patient_random.csv'),
#  PosixPath('../models/logs/ensemble_multi/full_ensemble_multi_backbones_patient_random.csv'),
# ...

# %%
# Out:
# ['../models/logs/cnn_extended/full_cnn_extended_image_random.csv',
#  '../models/logs/cnn_extended/full_cnn_extended_patient_random.csv',
#  '../models/logs/ensemble_efficientnetv2-s/full_ensemble_efficientnetv2-s_efficientnetv2-s_patient_random.csv',
#  '../models/logs/ensemble_efficientnetv2-s/full_ensemble_efficientnetv2-s_efficientnetv2-s_image_random.csv',
#  '../models/logs/ensemble_inception_v3/full_ensemble_inception_v3_inception_v3_patient_random.csv',
#  '../models/logs/ensemble_inception_v3/full_ensemble_inception_v3_inception_v3_image_random.csv',
#  '../models/logs/ensemble_resnet50v2/full_ensemble_resnet50v2_resnet50v2_image_random.csv',
#  '../models/logs/ensemble_resnet50v2/full_ensemble_resnet50v2_resnet50v2_patient_random.csv',
#  '../models/logs/ensemble_multi/full_ensemble_multi_backbones_patient_random.csv',
#  '../models/logs/ensemble_multi/full_ensemble_multi_backbones_image_random.csv',
# ...
